# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
csv = pd.read_csv("cifar-present.csv")
# csv = csv.loc[(csv['mode'].isin(['manifold'])) ^ (csv['eta'] == 1)]
# csv = csv.loc[~csv['mode'].str.contains('full')].loc[~csv['mode'].str.contains('one')].loc[~csv['mode'].str.contains('\*a-')]
csv
# Out:
#                                                   Name  setting  iteration  \
# 0    guide_mode=manifold+scale=30+label=5+setting=p...  present          1
# 1    guide_mode=manifold+scale=30+label=3+setting=p...  present          1
# 2    guide_mode=manifold+scale=30+label=9+setting=p...  present          1
# 3    guide_mode=manifold+scale=30+label=1+setting=p...  present          1
# 4    guide_mode=manifold+scale=30+label=7+setting=p...  present          1
# ..                                                 ...      ...        ...
# 355  guide_mode=manifold+scale=1+label=6+setting=pr...  present          1
# 356  guide_mode=manifold+scale=1+label=4+setting=pr...  present          1
# 357  guide_mode=manifold+scale=1+label=2+setting=pr...  present          1
# 358  guide_mode=manifold+scale=5+label=0+setting=pr...  present          1
# 359  guide_mode=manifold+scale=1+label=0+setting=pr...  present          1
#
#          mode  scale  timesteps  label  validity        fid        sfid  \
# 0    manifold     30        100      5    0.7534  93.263891  125.546138
# 1    manifold     30        100      3    0.6460  56.775036  127.547357
# 2    manifold     30        100      9    0.7471  52.592534  122.757409
# 3    manifold     30        100      1    0.8560  39.002990  120.491058
# 4    manifold     30        100      7    0.7378  53.828958  110.630960
# ..        ...    ...        ...    ...       ...        ...         ...
# 355  manifold      1        100      6    0.3101  85.391016  137.094328
# 356  manifold      1        100      4    0.3940  85.499462  131.514101
# 357  manifold      1        100      2    0.4331  67.989813  125.102017
# 358  manifold      5        100      0    0.4448  71.324802  120.698139
# 359  manifold      1        100      0    0.3242  78.000818  121.095117
#
#            is  precision  recall  shrink_x0
# 0    6.572525   0.593262   0.555      False
# 1    5.561142   0.514160   0.556      False
# 2    3.584584   0.441406   0.642      False
# 3    3.281746   0.639648   0.496      False
# 4    5.178079   0.476562   0.545      False
# ..        ...        ...     ...        ...
# 355  6.534340   0.401367   0.661      False
# 356  6.899522   0.540039   0.627      False
# 357  6.544625   0.637695   0.473      False
# 358  6.189012   0.442871   0.597      False
# 359  6.651104   0.444824   0.630      False
#
# [360 rows x 14 columns]

# %%
avg = csv.groupby(['mode', 'scale', 'timesteps']).mean(['validity', 'fid', 'sfid', 'is', 'precision', 'recall']).reset_index()
avg['mode-step'] = avg['mode'] + '-' + avg['timesteps'].astype(str)
avg
# Out:
#                      mode  scale  timesteps  iteration  label  validity  \
# 0   dynamic-two-0.1-a-did      1         50        1.0    4.5   0.36451
# 1   dynamic-two-0.1-a-did      5         50        1.0    4.5   0.59580
# 2   dynamic-two-0.1-a-did     10         50        1.0    4.5   0.67973
# 3   dynamic-two-0.1-a-did     15         50        1.0    4.5   0.71058
# 4   dynamic-two-0.1-a-did     20         50        1.0    4.5   0.71016
# 5   dynamic-two-0.1-a-did     25         50        1.0    4.5   0.71084
# 6   dynamic-two-0.1-a-did     30         50        1.0    4.5   0.70791
# 7   dynamic-two-0.1-a-did     50         50        1.0    4.5   0.68428
# 8   dynamic-two-0.1-a-did    100         50        1.0    4.5   0.63640
# 9     dynamic-two-0.1-did      1         50        1.0    4.5   0.36162
# 10    dynamic-two-0.1-did      5         50        1.0    4.5   0.58995
# 11    dynamic-two-0.1-did     10         50        1.0    4.5   0.67309
# 12    dynamic-two-0.1-did     15         50        1.0    4.5   0.70274
# 13    dynamic-two-0.1-did     20         50        1.0    4.5   0.70645
# 14    dynamic-two-0.1-did     25         50        1.0    4.5   0.70376
# 15    dynamic-two-0.1-did     30         50        1.0    4.5   0.70005
# 16    dynamic-two-0.1-did     50         50        1.0    4.5   0.67661
# 17    dynamic-two-0.1-did    100         50        1.0    4.5   0.63316
# 18               manifold      1         50        1.0    4.5   0.36993
# 19               manifold      1        100        1.0    4.5   0.35855
# 20               manifold      5         50        1.0    4.5   0.60005
# 21               manifold      5        100        1.0    4.5   0.55658
# 22               manifold     10         50        1.0    4.5   0.68361
# 23               manifold     10        100        1.0    4.5   0.64048
# 24               manifold     15         50        1.0    4.5   0.70772
# 25               manifold     15        100        1.0    4.5   0.68446
# 26               manifold     20         50        1.0    4.5   0.70816
# 27               manifold     20        100        1.0    4.5   0.70587
# 28               manifold     25         50        1.0    4.5   0.70358
# 29               manifold     25        100        1.0    4.5   0.72219
# 30               manifold     30         50        1.0    4.5   0.70176
# 31               manifold     30        100        1.0    4.5   0.73038
# 32               manifold     50         50        1.0    4.5   0.66695
# 33               manifold     50        100        1.0    4.5   0.73362
# 34               manifold    100         50        1.0    4.5   0.62027
# 35               manifold    100        100        1.0    4.5   0.70255
#
#            fid        sfid        is  precision  recall  shrink_x0  \
# 0    81.397590  130.780532  6.308565   0.433057  0.6278        0.0
# 1    58.306830  125.467872  5.391959   0.526025  0.6010        0.0
# 2    53.947576  124.751722  5.173079   0.553516  0.5831        0.0
# 3    54.513595  124.930777  5.085510   0.563818  0.5716        0.0
# 4    57.490912  125.499662  5.163830   0.555762  0.5614        0.0
# 5    60.766922  125.909449  5.265436   0.546484  0.5581        0.0
# 6    64.705941  126.693153  5.311376   0.539355  0.5395        0.0
# 7    77.456793  128.061953  5.451325   0.504346  0.5314        0.0
# 8    97.243626  130.130902  5.566980   0.452246  0.5099        0.0
# 9    83.196899  133.693869  6.268734   0.432666  0.6250        0.0
# 10   59.986717  128.272805  5.390044   0.520264  0.6013        0.0
# 11   55.238232  127.260831  5.164168   0.551318  0.5949        0.0
# 12   56.140149  127.364007  5.145120   0.553418  0.5703        0.0
# 13   58.726505  127.821659  5.192732   0.549756  0.5688        0.0
# 14   62.337435  128.244031  5.226677   0.536865  0.5486        0.0
# 15   65.929550  128.747337  5.296973   0.534521  0.5434        0.0
# 16   78.188596  129.908424  5.478560   0.500244  0.5292        0.0
# 17   97.084604  131.477670  5.591792   0.449365  0.5170        0.0
# 18   87.758490  125.299125  6.309935   0.399561  0.6060        0.0
# 19   84.052772  126.728223  6.533280   0.419336  0.6337        0.0
# 20   66.015698  121.009114  5.386107   0.493506  0.5604        0.0
# 21   63.391136  122.161966  5.590297   0.502295  0.5970        0.0
# 22   62.558949  120.889663  5.077505   0.527588  0.5369        0.0
# 23   57.876516  121.279014  5.181032   0.533105  0.5848        0.0
# 24   64.190355  121.432550  5.047832   0.534766  0.5163        0.0
# 25   56.207084  121.341571  5.118288   0.555176  0.5607        0.0
# 26   67.555980  122.433237  5.037636   0.529687  0.5114        0.0
# 27   56.173684  121.716193  5.014028   0.560352  0.5531        0.0
# 28   71.649860  123.125599  5.127413   0.518799  0.4907        0.0
# 29   56.409372  122.238376  4.957166   0.565723  0.5467        0.0
# 30   76.130363  124.011405  5.141612   0.512695  0.4947        0.0
# 31   57.694587  122.415208  5.007434   0.565186  0.5302        0.0
# 32   89.920063  126.395588  5.264838   0.479980  0.4600        0.0
# 33   63.225274  123.937367  5.033699   0.557959  0.5229        0.0
# 34  109.754619  129.387831  5.312128   0.435156  0.4472        0.0
# 35   78.280727  126.550117  5.247493   0.515527  0.4932        0.0
#
#                    mode-step
# 0   dynamic-two-0.1-a-did-50
# 1   dynamic-two-0.1-a-did-50
# 2   dynamic-two-0.1-a-did-50
# 3   dynamic-two-0.1-a-did-50
# 4   dynamic-two-0.1-a-did-50
# 5   dynamic-two-0.1-a-did-50
# 6   dynamic-two-0.1-a-did-50
# 7   dynamic-two-0.1-a-did-50
# 8   dynamic-two-0.1-a-did-50
# 9     dynamic-two-0.1-did-50
# 10    dynamic-two-0.1-did-50
# 11    dynamic-two-0.1-did-50
# 12    dynamic-two-0.1-did-50
# 13    dynamic-two-0.1-did-50
# 14    dynamic-two-0.1-did-50
# 15    dynamic-two-0.1-did-50
# 16    dynamic-two-0.1-did-50
# 17    dynamic-two-0.1-did-50
# 18               manifold-50
# 19              manifold-100
# 20               manifold-50
# 21              manifold-100
# 22               manifold-50
# 23              manifold-100
# 24               manifold-50
# 25              manifold-100
# 26               manifold-50
# 27              manifold-100
# 28               manifold-50
# 29              manifold-100
# 30               manifold-50
# 31              manifold-100
# 32               manifold-50
# 33              manifold-100
# 34               manifold-50
# 35              manifold-100

# %%
# data = avg.loc[avg['mode'] == 'manifold']
data = avg.loc[~avg['mode-step'].isin(['manifold-100', 'dynamic-two-0.1-did-50'])]
data['scale'] = data['scale'].map(lambda x: str(x))
# data = data.loc[data['validity'] > 0.6]
# data = data.loc[data['fid']<70]
# data['eta-scale'] = data['eta'].astype(str) + '-' + data['scale'].astype(str)

# data['scale'] = data['scale'].map(lambda x: str(x))
plt.figure(figsize=(10,10), dpi=100)
sns.scatterplot(data=data, x='fid', y='validity', hue='scale', style='mode', s=100)
# Out:
# /tmp/user/23218/ipykernel_3600384/381482555.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['scale'] = data['scale'].map(lambda x: str(x))
# <Axes: xlabel='fid', ylabel='validity'>

# %%
data = csv.loc[csv['scale'] == 20]
sns.barplot(data=data, x='label', y='fid', hue='mode')#, style='mode')
plt.ylim(30, 120)
# Out:
# (30.0, 120.0)

# %%
csv = pd.read_csv("CIFAR+combine(part).csv")
# csv = csv.loc[(csv['mode'].isin(['manifold'])) ^ (csv['eta'] == 1)]
csv = csv.loc[~csv['mode'].str.contains('full')].loc[~csv['mode'].str.contains('one')].loc[~csv['mode'].str.contains('\*a-')]
csv
# Out:
#                                                   Name  \
# 0              guide_mode=classifier+scale=0.1+label=8
# 1              guide_mode=classifier+scale=0.1+label=6
# 2    guide_mode=dynamic-two-0.5*a*(1-a)+scale=20+la...
# 3    guide_mode=dynamic-two-0.1*a*(1-a)+scale=20+la...
# 4            guide_mode=dynamic-fonly+scale=20+label=1
# ..                                                 ...
# 410               guide_mode=manifold+scale=20+label=6
# 411               guide_mode=manifold+scale=20+label=8
# 412               guide_mode=manifold+scale=50+label=1
# 413               guide_mode=manifold+scale=50+label=6
# 414               guide_mode=manifold+scale=50+label=8
#
#                         mode  scale  label  eta  validity         fid  \
# 0                 classifier    0.1      8    1    0.3652   91.932738
# 1                 classifier    0.1      6    1    0.2471   90.925637
# 2    dynamic-two-0.5*a*(1-a)   20.0      1    1    0.8208   39.476015
# 3    dynamic-two-0.1*a*(1-a)   20.0      1    1    0.8135   40.359251
# 4              dynamic-fonly   20.0      1    1    0.8174   41.016895
# ..                       ...    ...    ...  ...       ...         ...
# 410                 manifold   20.0      6    0    0.4658  128.547993
# 411                 manifold   20.0      8    0    0.7637   53.479205
# 412                 manifold   50.0      1    0    0.7295   99.500889
# 413                 manifold   50.0      6    0    0.5049  142.991670
# 414                 manifold   50.0      8    0    0.8091   68.823923
#
#            sfid        is  precision  recall
# 0    114.626943  7.021482   0.350586   0.570
# 1    137.488113  6.851516   0.373047   0.574
# 2    122.032979  3.341644   0.606445   0.517
# 3    120.499850  3.390682   0.585938   0.474
# 4    120.525200  3.403000   0.583984   0.443
# ..          ...       ...        ...     ...
# 410  154.099395  5.139782   0.400879   0.502
# 411  114.970846  3.942854   0.534180   0.399
# 412  139.139870  3.925016   0.419922   0.276
# 413  155.255786  5.140246   0.392090   0.431
# 414  117.351438  4.011956   0.489746   0.376
#
# [265 rows x 11 columns]

# %%
# concert avg into a half table such that all eta = 0 and eta = 1 are concated in the same rows some long as the mode, scale are the same
avg = csv.pivot_table(index=['mode', 'scale', 'label'], columns='eta', values=['validity', 'fid', 'sfid', 'is', 'precision', 'recall'])
avg = avg.reset_index()
avg.columns = ["_".join([str(t) for t in w if t!='']) for w in avg.columns.values]
avg
# Out:
#            mode  scale  label       fid_0       fid_1      is_0      is_1  \
# 0    classifier   0.10      1   73.036794   91.316010  5.598959  6.622758
# 1    classifier   0.10      6   71.618125   90.925637  6.340681  6.851516
# 2    classifier   0.10      8   65.884177   91.932738  5.978353  7.021482
# 3    classifier   0.25      1   39.747365   50.804675  3.821718  4.372647
# 4    classifier   0.25      6   43.096277   60.222134  4.288852  5.336592
# ..          ...    ...    ...         ...         ...       ...       ...
# 130    manifold  20.00      6  128.547993   97.721244  5.139782  5.618134
# 131    manifold  20.00      8   53.479205   70.601545  3.942854  4.599549
# 132    manifold  50.00      1   99.500889   78.389110  3.925016  4.274128
# 133    manifold  50.00      6  142.991670  124.127553  5.140246  5.672109
# 134    manifold  50.00      8   68.823923   88.271165  4.011956  4.982554
#
#      precision_0  precision_1  recall_0  recall_1      sfid_0      sfid_1  \
# 0       0.368164     0.265625     0.644     0.627  127.635854  128.387383
# 1       0.438965     0.373047     0.647     0.574  134.625245  137.488113
# 2       0.419434     0.350586     0.568     0.570  115.120386  114.626943
# 3       0.555176     0.458496     0.538     0.554  117.630030  116.152275
# 4       0.612305     0.483398     0.589     0.553  131.381522  130.325553
# ..           ...          ...       ...       ...         ...         ...
# 130     0.400879     0.461426     0.502     0.460  154.099395  142.901684
# 131     0.534180     0.482422     0.399     0.403  114.970846  115.153924
# 132     0.419922     0.431152     0.276     0.379  139.139870  125.010881
# 133     0.392090     0.395020     0.431     0.400  155.255786  149.017778
# 134     0.489746     0.427246     0.376     0.369  117.351438  117.174799
#
#      validity_0  validity_1
# 0        0.3765      0.2544
# 1        0.3550      0.2471
# 2        0.4980      0.3652
# 3        0.6982      0.5557
# 4        0.6582      0.4985
# ..          ...         ...
# 130      0.4658      0.5610
# 131      0.7637      0.7637
# 132      0.7295      0.7456
# 133      0.5049      0.4976
# 134      0.8091      0.6855
#
# [135 rows x 15 columns]

# %%
data = avg.loc[~avg.isna().any(axis=1)]
data = data.loc[data['scale'] < 100]
data['scale'] = data['scale'].map(lambda x: str(x))

fig, axs= plt.subplots(nrows=1, ncols=2, figsize=(22, 10), dpi=100)

sns.scatterplot(data=data, x='fid_0', y='fid_1', hue='scale', style='mode', s=100, ax=axs[0])
axs[0].set_title("Comparison of FID between eta=0 and eta=1")
axs[0].legend(loc='upper left')
l, r = 25, 100
axs[0].set_xlim(l,r)
axs[0].set_ylim(l,r)
axs[0].plot([l,r], [l,r], 'r--')

sns.scatterplot(data=data, x='validity_0', y='validity_1', hue='scale', style='mode', s=100, ax=axs[1])
axs[1].set_title("Comparison of Validity between eta=0 and eta=1")
axs[1].legend(loc='lower right')
l, r = 0.6, 1
axs[1].set_xlim(l, r)
axs[1].set_ylim(l, r)
axs[1].plot([l,r], [l,r], 'r--')
