# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
csv = pd.read_csv("celebA-noiter.csv")
# csv = csv.loc[(csv['mode'].isin(['manifold'])) ^ (csv['eta'] == 1)]
# csv = csv.loc[~csv['mode'].str.contains('full')].loc[~csv['mode'].str.contains('one')].loc[~csv['mode'].str.contains('\*a-')]
csv
# Out:
#                                                   Name               mode  \
# 0    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 1    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 2    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 3    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 4    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# ..                                                 ...                ...
# 142  guide_mode=manifold+scale=500+target=03437+los...           manifold
# 143  guide_mode=manifold+scale=500+target=14255+los...           manifold
# 144  guide_mode=manifold+scale=500+target=14255+los...           manifold
# 145  guide_mode=manifold+scale=500+target=21177+los...           manifold
# 146  guide_mode=manifold+scale=500+target=21177+los...           manifold
#
#      scale  label       kid         fid        sfid    faceid losstype  eta
# 0      100   3437  0.044453   54.288973  126.654543  0.809262   cosine  1.0
# 1      100   3437  0.044460   54.286299  126.645446  0.809256       l2  1.0
# 2      100  14255  0.044330   54.153013  127.010966  0.782628   cosine  1.0
# 3      100  14255  0.044350   54.162664  127.013620  0.782629       l2  1.0
# 4      100  21177  0.044203   54.014759  127.195326  0.939074   cosine  1.0
# ..     ...    ...       ...         ...         ...       ...      ...  ...
# 142    500   3437  0.079160   88.780169  195.985374  0.392973       l2  1.0
# 143    500  14255  0.049150   66.211840  168.882202  0.268492   cosine  0.5
# 144    500  14255  0.049205   66.750159  168.938028  0.268029       l2  0.5
# 145    500  21177  0.115585  115.438331  203.689862  0.391255   cosine  0.5
# 146    500  21177  0.114828  114.952240  203.498073  0.392460       l2  0.5
#
# [147 rows x 10 columns]

# %%
subcsv = csv.loc[csv['eta'] == 1]
subcsv
# Out:
#                                                   Name               mode  \
# 0    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 1    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 2    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 3    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# 4    guide_mode=dynamic-nog-0.1*a+scale=100+target=...  dynamic-nog-0.1*a
# ..                                                 ...                ...
# 133  guide_mode=manifold+scale=50+target=14255+loss...           manifold
# 135  guide_mode=manifold+scale=50+target=14255+loss...           manifold
# 137  guide_mode=manifold+scale=50+target=21177+loss...           manifold
# 139  guide_mode=manifold+scale=50+target=21177+loss...           manifold
# 142  guide_mode=manifold+scale=500+target=03437+los...           manifold
#
#      scale  label       kid        fid        sfid    faceid losstype  eta
# 0      100   3437  0.044453  54.288973  126.654543  0.809262   cosine  1.0
# 1      100   3437  0.044460  54.286299  126.645446  0.809256       l2  1.0
# 2      100  14255  0.044330  54.153013  127.010966  0.782628   cosine  1.0
# 3      100  14255  0.044350  54.162664  127.013620  0.782629       l2  1.0
# 4      100  21177  0.044203  54.014759  127.195326  0.939074   cosine  1.0
# ..     ...    ...       ...        ...         ...       ...      ...  ...
# 133     50  14255  0.026466  42.391882  128.340144  0.431186   cosine  1.0
# 135     50  14255  0.026475  42.482556  128.273883  0.430031       l2  1.0
# 137     50  21177  0.027770  43.307805  131.319633  0.611467   cosine  1.0
# 139     50  21177  0.027733  43.318182  131.376854  0.611316       l2  1.0
# 142    500   3437  0.079160  88.780169  195.985374  0.392973       l2  1.0
#
# [113 rows x 10 columns]

# %%
avg = subcsv.groupby(['mode', 'scale', 'losstype']).mean(['kid', 'fid', 'sfid', 'faceid']).reset_index()
avg
# Out:
#                        mode  scale losstype         label       kid  \
# 0         dynamic-nog-0.1*a    100   cosine  12956.333333  0.044328
# 1         dynamic-nog-0.1*a    100       l2  12956.333333  0.044338
# 2         dynamic-nog-0.1*a    200   cosine  12956.333333  0.044555
# 3         dynamic-nog-0.1*a    200       l2  12956.333333  0.044539
# 4         dynamic-nog-0.1*a    500   cosine  12956.333333  0.044791
# 5         dynamic-nog-0.1*a    500       l2  12956.333333  0.044772
# 6         dynamic-nog-0.1*a   1000   cosine   3437.000000  0.047406
# 7         dynamic-nog-0.1*a   1000       l2  14255.000000  0.045174
# 8         dynamic-nog-0.5*a    100   cosine   8846.000000  0.045509
# 9         dynamic-nog-0.5*a    100       l2  12956.333333  0.045472
# 10        dynamic-nog-0.5*a    200   cosine  12956.333333  0.045417
# 11        dynamic-nog-0.5*a    200       l2  12956.333333  0.045423
# 12        dynamic-nog-0.5*a    500   cosine  12956.333333  0.044865
# 13        dynamic-nog-0.5*a    500       l2  12956.333333  0.044834
# 14        dynamic-nog-0.5*a   1000   cosine  12956.333333  0.043997
# 15        dynamic-nog-0.5*a   1000       l2  12956.333333  0.044004
# 16  dynamic-two-0.1*a*(1-a)    100   cosine  12956.333333  0.031564
# 17  dynamic-two-0.1*a*(1-a)    100       l2  12956.333333  0.031576
# 18  dynamic-two-0.1*a*(1-a)    200   cosine  12956.333333  0.031707
# 19  dynamic-two-0.1*a*(1-a)    200       l2  12956.333333  0.031714
# 20  dynamic-two-0.1*a*(1-a)    500   cosine  12956.333333  0.031512
# 21  dynamic-two-0.1*a*(1-a)    500       l2  12956.333333  0.031522
# 22  dynamic-two-0.1*a*(1-a)   1000   cosine  17716.000000  0.029788
# 23  dynamic-two-0.5*a*(1-a)    100   cosine  12956.333333  0.030711
# 24  dynamic-two-0.5*a*(1-a)    100       l2  12956.333333  0.030714
# 25  dynamic-two-0.5*a*(1-a)    200   cosine  12956.333333  0.031019
# 26  dynamic-two-0.5*a*(1-a)    200       l2  12956.333333  0.031006
# 27  dynamic-two-0.5*a*(1-a)    500   cosine  12956.333333  0.031378
# 28  dynamic-two-0.5*a*(1-a)    500       l2  12956.333333  0.031384
# 29  dynamic-two-0.5*a*(1-a)   1000   cosine  12956.333333  0.031659
# 30  dynamic-two-0.5*a*(1-a)   1000       l2  12956.333333  0.031670
# 31                 manifold     10   cosine  12956.333333  0.030149
# 32                 manifold     10       l2  12956.333333  0.030146
# 33                 manifold     50   cosine  12956.333333  0.027821
# 34                 manifold     50       l2  12956.333333  0.027811
# 35                 manifold    100   cosine  12956.333333  0.032514
# 36                 manifold    100       l2  12956.333333  0.032532
# 37                 manifold    200   cosine  12956.333333  0.046230
# 38                 manifold    200       l2  12956.333333  0.046377
# 39                 manifold    500       l2   3437.000000  0.079160
# 40                 manifold   1000   cosine   3437.000000  0.113223
#
#            fid        sfid    faceid  eta
# 0    54.152248  126.953612  0.843655  1.0
# 1    54.155736  126.947777  0.843651  1.0
# 2    54.432345  127.605651  0.761147  1.0
# 3    54.423233  127.611656  0.761152  1.0
# 4    54.682202  130.033701  0.619968  1.0
# 5    54.663537  130.027379  0.620003  1.0
# 6    57.175100  133.731579  0.500359  1.0
# 7    55.147044  132.834278  0.419658  1.0
# 8    57.222716  139.228195  0.798874  1.0
# 9    57.209899  139.348358  0.845820  1.0
# 10   57.261857  140.242635  0.764867  1.0
# 11   57.268683  140.235702  0.764867  1.0
# 12   57.144949  143.121529  0.625840  1.0
# 13   57.103686  143.088006  0.625782  1.0
# 14   56.661772  147.553386  0.512323  1.0
# 15   56.714553  147.583192  0.512326  1.0
# 16   44.506240  121.135105  0.839221  1.0
# 17   44.516137  121.137824  0.839218  1.0
# 18   44.680507  121.631736  0.755205  1.0
# 19   44.682334  121.632015  0.755195  1.0
# 20   44.733158  123.678716  0.612786  1.0
# 21   44.749754  123.672266  0.612804  1.0
# 22   43.712865  127.545008  0.502919  1.0
# 23   43.948086  122.873166  0.832704  1.0
# 24   43.950279  122.873840  0.832701  1.0
# 25   44.187956  123.329733  0.747194  1.0
# 26   44.179133  123.329755  0.747196  1.0
# 27   44.628729  125.306714  0.604206  1.0
# 28   44.631675  125.301720  0.604225  1.0
# 29   45.260632  129.219667  0.493200  1.0
# 30   45.271678  129.203856  0.493220  1.0
# 31   43.672885  121.396284  0.685843  1.0
# 32   43.669136  121.400231  0.685844  1.0
# 33   43.381623  130.187214  0.515092  1.0
# 34   43.388796  130.187593  0.514738  1.0
# 35   48.839618  141.894213  0.467999  1.0
# 36   48.902270  141.992733  0.466438  1.0
# 37   61.063858  158.991077  0.423160  1.0
# 38   61.224006  159.106027  0.424098  1.0
# 39   88.780169  195.985374  0.392973  1.0
# 40  114.824107  219.175625  0.362713  1.0

# %%
# data = avg.loc[avg['mode'] == 'manifold']
data = avg.loc[avg['losstype'] == 'l2'].loc[avg['scale'] < 1000]
# data = data.loc[data['validity'] > 0.6]
# data = data.loc[data['fid']<70]
data['loss-scale'] = data['losstype'].astype(str) + '-' + data['scale'].astype(str).map(lambda x: x.rjust(4, '0'))

# data['scale'] = data['scale'].map(lambda x: str(x))
plt.figure(figsize=(10,10), dpi=100)
sns.scatterplot(data=data, x='kid', y='faceid', hue='loss-scale', style='mode', s=100, hue_order=sorted(data['loss-scale'].unique()))
# Out:
# <Axes: xlabel='kid', ylabel='faceid'>

# %%
csv.loc[csv['mode'].isin(['manifold', 'dynamic-fonly'])].loc[csv['label'] == 1].sort_values(by=['mode', 'scale'])
# Out:
#                                            Name           mode  scale  label  \
# 102    guide_mode=dynamic-fonly+scale=2+label=1  dynamic-fonly    2.0      1
# 25     guide_mode=dynamic-fonly+scale=5+label=1  dynamic-fonly    5.0      1
# 4     guide_mode=dynamic-fonly+scale=20+label=1  dynamic-fonly   20.0      1
# 28    guide_mode=dynamic-fonly+scale=50+label=1  dynamic-fonly   50.0      1
# 65   guide_mode=dynamic-fonly+scale=100+label=1  dynamic-fonly  100.0      1
# 15          guide_mode=manifold+scale=1+label=1       manifold    1.0      1
# 5           guide_mode=manifold+scale=2+label=1       manifold    2.0      1
# 8           guide_mode=manifold+scale=5+label=1       manifold    5.0      1
# 56         guide_mode=manifold+scale=20+label=1       manifold   20.0      1
# 110        guide_mode=manifold+scale=50+label=1       manifold   50.0      1
#
#      validity        fid        sfid        is  precision  recall
# 102    0.3813  77.318172  124.520638  5.586083   0.329590   0.615
# 25     0.5913  51.794021  118.781807  4.395249   0.461426   0.558
# 4      0.8174  41.016895  120.525200  3.403000   0.583984   0.443
# 28     0.8403  53.079123  126.083413  3.457582   0.559082   0.384
# 65     0.8120  64.265418  126.881540  3.983398   0.479492   0.442
# 15     0.6523  48.452983  118.477048  4.190792   0.482422   0.559
# 5      0.7583  41.127577  117.742019  3.625943   0.551270   0.517
# 8      0.8374  43.015129  120.601504  3.541133   0.593750   0.453
# 56     0.8164  61.726525  127.401138  3.763835   0.516113   0.423
# 110    0.7456  78.389110  125.010881  4.274128   0.431152   0.379

# %%
csv = pd.read_csv("CIFAR+combine(part).csv")
# csv = csv.loc[(csv['mode'].isin(['manifold'])) ^ (csv['eta'] == 1)]
csv = csv.loc[~csv['mode'].str.contains('full')].loc[~csv['mode'].str.contains('one')].loc[~csv['mode'].str.contains('\*a-')]
csv
# Out:
#                                                   Name  \
# 0              guide_mode=classifier+scale=0.1+label=8
# 1              guide_mode=classifier+scale=0.1+label=6
# 2    guide_mode=dynamic-two-0.5*a*(1-a)+scale=20+la...
# 3    guide_mode=dynamic-two-0.1*a*(1-a)+scale=20+la...
# 4            guide_mode=dynamic-fonly+scale=20+label=1
# ..                                                 ...
# 410               guide_mode=manifold+scale=20+label=6
# 411               guide_mode=manifold+scale=20+label=8
# 412               guide_mode=manifold+scale=50+label=1
# 413               guide_mode=manifold+scale=50+label=6
# 414               guide_mode=manifold+scale=50+label=8
#
#                         mode  scale  label  eta  validity         fid  \
# 0                 classifier    0.1      8    1    0.3652   91.932738
# 1                 classifier    0.1      6    1    0.2471   90.925637
# 2    dynamic-two-0.5*a*(1-a)   20.0      1    1    0.8208   39.476015
# 3    dynamic-two-0.1*a*(1-a)   20.0      1    1    0.8135   40.359251
# 4              dynamic-fonly   20.0      1    1    0.8174   41.016895
# ..                       ...    ...    ...  ...       ...         ...
# 410                 manifold   20.0      6    0    0.4658  128.547993
# 411                 manifold   20.0      8    0    0.7637   53.479205
# 412                 manifold   50.0      1    0    0.7295   99.500889
# 413                 manifold   50.0      6    0    0.5049  142.991670
# 414                 manifold   50.0      8    0    0.8091   68.823923
#
#            sfid        is  precision  recall
# 0    114.626943  7.021482   0.350586   0.570
# 1    137.488113  6.851516   0.373047   0.574
# 2    122.032979  3.341644   0.606445   0.517
# 3    120.499850  3.390682   0.585938   0.474
# 4    120.525200  3.403000   0.583984   0.443
# ..          ...       ...        ...     ...
# 410  154.099395  5.139782   0.400879   0.502
# 411  114.970846  3.942854   0.534180   0.399
# 412  139.139870  3.925016   0.419922   0.276
# 413  155.255786  5.140246   0.392090   0.431
# 414  117.351438  4.011956   0.489746   0.376
#
# [265 rows x 11 columns]

# %%
# concert avg into a half table such that all eta = 0 and eta = 1 are concated in the same rows some long as the mode, scale are the same
avg = csv.pivot_table(index=['mode', 'scale', 'label'], columns='eta', values=['validity', 'fid', 'sfid', 'is', 'precision', 'recall'])
avg = avg.reset_index()
avg.columns = ["_".join([str(t) for t in w if t!='']) for w in avg.columns.values]
avg
# Out:
#            mode  scale  label       fid_0       fid_1      is_0      is_1  \
# 0    classifier   0.10      1   73.036794   91.316010  5.598959  6.622758
# 1    classifier   0.10      6   71.618125   90.925637  6.340681  6.851516
# 2    classifier   0.10      8   65.884177   91.932738  5.978353  7.021482
# 3    classifier   0.25      1   39.747365   50.804675  3.821718  4.372647
# 4    classifier   0.25      6   43.096277   60.222134  4.288852  5.336592
# ..          ...    ...    ...         ...         ...       ...       ...
# 130    manifold  20.00      6  128.547993   97.721244  5.139782  5.618134
# 131    manifold  20.00      8   53.479205   70.601545  3.942854  4.599549
# 132    manifold  50.00      1   99.500889   78.389110  3.925016  4.274128
# 133    manifold  50.00      6  142.991670  124.127553  5.140246  5.672109
# 134    manifold  50.00      8   68.823923   88.271165  4.011956  4.982554
#
#      precision_0  precision_1  recall_0  recall_1      sfid_0      sfid_1  \
# 0       0.368164     0.265625     0.644     0.627  127.635854  128.387383
# 1       0.438965     0.373047     0.647     0.574  134.625245  137.488113
# 2       0.419434     0.350586     0.568     0.570  115.120386  114.626943
# 3       0.555176     0.458496     0.538     0.554  117.630030  116.152275
# 4       0.612305     0.483398     0.589     0.553  131.381522  130.325553
# ..           ...          ...       ...       ...         ...         ...
# 130     0.400879     0.461426     0.502     0.460  154.099395  142.901684
# 131     0.534180     0.482422     0.399     0.403  114.970846  115.153924
# 132     0.419922     0.431152     0.276     0.379  139.139870  125.010881
# 133     0.392090     0.395020     0.431     0.400  155.255786  149.017778
# 134     0.489746     0.427246     0.376     0.369  117.351438  117.174799
#
#      validity_0  validity_1
# 0        0.3765      0.2544
# 1        0.3550      0.2471
# 2        0.4980      0.3652
# 3        0.6982      0.5557
# 4        0.6582      0.4985
# ..          ...         ...
# 130      0.4658      0.5610
# 131      0.7637      0.7637
# 132      0.7295      0.7456
# 133      0.5049      0.4976
# 134      0.8091      0.6855
#
# [135 rows x 15 columns]

# %%
data = avg.loc[~avg.isna().any(axis=1)]
data = data.loc[data['scale'] < 100]
data['scale'] = data['scale'].map(lambda x: str(x))

fig, axs= plt.subplots(nrows=1, ncols=2, figsize=(22, 10), dpi=100)

sns.scatterplot(data=data, x='fid_0', y='fid_1', hue='scale', style='mode', s=100, ax=axs[0])
axs[0].set_title("Comparison of FID between eta=0 and eta=1")
axs[0].legend(loc='upper left')
l, r = 25, 100
axs[0].set_xlim(l,r)
axs[0].set_ylim(l,r)
axs[0].plot([l,r], [l,r], 'r--')

sns.scatterplot(data=data, x='validity_0', y='validity_1', hue='scale', style='mode', s=100, ax=axs[1])
axs[1].set_title("Comparison of Validity between eta=0 and eta=1")
axs[1].legend(loc='lower right')
l, r = 0.6, 1
axs[1].set_xlim(l, r)
axs[1].set_ylim(l, r)
axs[1].plot([l,r], [l,r], 'r--')
