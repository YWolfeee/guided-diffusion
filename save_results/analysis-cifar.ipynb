# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
csv = pd.read_csv("CIFAR+combine.csv")
# csv = csv.loc[(csv['mode'].isin(['manifold'])) ^ (csv['eta'] == 1)]
csv = csv.loc[~csv['mode'].str.contains('full')].loc[~csv['mode'].str.contains('one')].loc[~csv['mode'].str.contains('\*a-')]
csv
# Out:
#                                                   Name  \
# 0              guide_mode=classifier+scale=0.1+label=8
# 1              guide_mode=classifier+scale=0.1+label=6
# 2    guide_mode=dynamic-two-0.5*a*(1-a)+scale=20+la...
# 3    guide_mode=dynamic-two-0.1*a*(1-a)+scale=20+la...
# 4            guide_mode=dynamic-fonly+scale=20+label=1
# ..                                                 ...
# 410               guide_mode=manifold+scale=20+label=6
# 411               guide_mode=manifold+scale=20+label=8
# 412               guide_mode=manifold+scale=50+label=1
# 413               guide_mode=manifold+scale=50+label=6
# 414               guide_mode=manifold+scale=50+label=8
#
#                         mode  scale  label  eta  validity         fid  \
# 0                 classifier    0.1      8    1    0.3652   91.932738
# 1                 classifier    0.1      6    1    0.2471   90.925637
# 2    dynamic-two-0.5*a*(1-a)   20.0      1    1    0.8208   39.476015
# 3    dynamic-two-0.1*a*(1-a)   20.0      1    1    0.8135   40.359251
# 4              dynamic-fonly   20.0      1    1    0.8174   41.016895
# ..                       ...    ...    ...  ...       ...         ...
# 410                 manifold   20.0      6    0    0.4658  128.547993
# 411                 manifold   20.0      8    0    0.7637   53.479205
# 412                 manifold   50.0      1    0    0.7295   99.500889
# 413                 manifold   50.0      6    0    0.5049  142.991670
# 414                 manifold   50.0      8    0    0.8091   68.823923
#
#            sfid        is  precision  recall
# 0    114.626943  7.021482   0.350586   0.570
# 1    137.488113  6.851516   0.373047   0.574
# 2    122.032979  3.341644   0.606445   0.517
# 3    120.499850  3.390682   0.585938   0.474
# 4    120.525200  3.403000   0.583984   0.443
# ..          ...       ...        ...     ...
# 410  154.099395  5.139782   0.400879   0.502
# 411  114.970846  3.942854   0.534180   0.399
# 412  139.139870  3.925016   0.419922   0.276
# 413  155.255786  5.140246   0.392090   0.431
# 414  117.351438  4.011956   0.489746   0.376
#
# [265 rows x 11 columns]

# %%
csv.loc[csv['mode'] == 'manifold'].loc[csv['label'] == 1].sort_values('validity', ascending=False)[:20]
# Out:
#                                      Name      mode  scale  label  eta  \
# 8     guide_mode=manifold+scale=5+label=1  manifold    5.0      1    1
# 56   guide_mode=manifold+scale=20+label=1  manifold   20.0      1    1
# 226   guide_mode=manifold+scale=5+label=1  manifold    5.0      1    0
# 5     guide_mode=manifold+scale=2+label=1  manifold    2.0      1    1
# 228  guide_mode=manifold+scale=20+label=1  manifold   20.0      1    0
# 110  guide_mode=manifold+scale=50+label=1  manifold   50.0      1    1
# 229  guide_mode=manifold+scale=50+label=1  manifold   50.0      1    0
# 230   guide_mode=manifold+scale=2+label=1  manifold    2.0      1    0
# 15    guide_mode=manifold+scale=1+label=1  manifold    1.0      1    1
# 233   guide_mode=manifold+scale=1+label=1  manifold    1.0      1    0
#
#      validity         fid        sfid        is  precision  recall
# 8      0.8374   43.015129  120.601504  3.541133   0.593750   0.453
# 56     0.8164   61.726525  127.401138  3.763835   0.516113   0.423
# 226    0.7964   72.999255  139.026885  3.571803   0.489746   0.354
# 5      0.7583   41.127577  117.742019  3.625943   0.551270   0.517
# 228    0.7539  101.861329  147.203607  3.658512   0.397949   0.303
# 110    0.7456   78.389110  125.010881  4.274128   0.431152   0.379
# 229    0.7295   99.500889  139.139870  3.925016   0.419922   0.276
# 230    0.6929   52.662739  126.936566  3.662592   0.521484   0.495
# 15     0.6523   48.452983  118.477048  4.190792   0.482422   0.559
# 233    0.5698   56.208137  125.852261  4.239143   0.455078   0.599

# %%
avg = csv.groupby(['mode', 'scale', 'eta']).mean(['validity', 'fid', 'sfid', 'is', 'precision', 'recall']).reset_index()
avg
# Out:
#                        mode   scale  eta  label  validity         fid  \
# 0                classifier    0.10    1   5.00  0.288900   91.391462
# 1                classifier    0.25    1   5.00  0.589367   53.712146
# 2                classifier    0.50    1   5.00  0.790700   39.151420
# 3                classifier    1.00    1   5.00  0.902500   39.480449
# 4                classifier    2.00    1   5.00  0.951333   48.992927
# 5             dynamic-fonly    2.00    1   5.00  0.405400   80.611715
# 6             dynamic-fonly    5.00    1   5.00  0.585433   59.196403
# 7             dynamic-fonly   20.00    1   5.00  0.776667   48.033505
# 8             dynamic-fonly   50.00    1   5.00  0.763033   61.727397
# 9             dynamic-fonly  100.00    1   5.00  0.715633   78.726830
# 10          dynamic-nog-0.1    2.00    1   5.00  0.409667   90.302820
# 11          dynamic-nog-0.1    5.00    1   5.00  0.592300   68.145148
# 12          dynamic-nog-0.1   20.00    1   5.00  0.777500   55.815838
# 13          dynamic-nog-0.1   50.00    1   5.00  0.759100   68.806288
# 14          dynamic-nog-0.1  100.00    1   5.00  0.707367   84.254678
# 15        dynamic-nog-0.1*a    2.00    1   5.00  0.406400   88.473156
# 16        dynamic-nog-0.1*a    5.00    1   5.00  0.586933   66.648271
# 17        dynamic-nog-0.1*a   20.00    1   5.00  0.771967   54.594862
# 18        dynamic-nog-0.1*a   50.00    1   5.00  0.761067   67.701454
# 19        dynamic-nog-0.1*a  100.00    1   5.00  0.705733   84.960825
# 20          dynamic-nog-0.5    2.00    1   5.00  0.383933  119.913831
# 21          dynamic-nog-0.5    5.00    1   5.00  0.567700  100.140874
# 22          dynamic-nog-0.5   20.00    1   5.00  0.758633   82.932391
# 23          dynamic-nog-0.5   50.00    1   5.00  0.744300   92.054325
# 24          dynamic-nog-0.5  100.00    1   5.00  0.680000  106.392873
# 25        dynamic-nog-0.5*a    2.00    1   5.00  0.403500  111.569921
# 26        dynamic-nog-0.5*a    5.00    1   5.00  0.574533   91.672731
# 27        dynamic-nog-0.5*a   20.00    1   5.00  0.764133   76.068727
# 28        dynamic-nog-0.5*a   50.00    1   5.00  0.749667   86.650858
# 29        dynamic-nog-0.5*a  100.00    1   5.00  0.694833  100.916135
# 30  dynamic-two-0.1*a*(1-a)    2.00    1   5.00  0.401867   79.293323
# 31  dynamic-two-0.1*a*(1-a)    5.00    1   5.00  0.583667   58.000131
# 32  dynamic-two-0.1*a*(1-a)   20.00    1   5.00  0.774600   46.822704
# 33  dynamic-two-0.1*a*(1-a)   50.00    1   5.00  0.767233   60.119194
# 34  dynamic-two-0.1*a*(1-a)  100.00    1   5.00  0.708800   77.607612
# 35  dynamic-two-0.5*a*(1-a)    2.00    1   5.00  0.398267   76.710466
# 36  dynamic-two-0.5*a*(1-a)    5.00    1   5.00  0.579567   55.912158
# 37  dynamic-two-0.5*a*(1-a)   20.00    1   5.00  0.775567   44.191556
# 38  dynamic-two-0.5*a*(1-a)   50.00    1   5.00  0.766600   57.228524
# 39  dynamic-two-0.5*a*(1-a)  100.00    1   5.00  0.713667   72.978532
# 40                 manifold    1.00    0   5.75  0.504525   66.965273
# 41                 manifold    1.00    1   5.00  0.633100   56.384842
# 42                 manifold    2.00    0   5.00  0.572300   64.697752
# 43                 manifold    2.00    1   5.00  0.742033   48.367653
# 44                 manifold    5.00    0   5.00  0.642433   75.087990
# 45                 manifold    5.00    1   5.00  0.796533   50.477113
# 46                 manifold   20.00    0   5.00  0.661133   94.629509
# 47                 manifold   20.00    1   5.00  0.713700   76.683105
# 48                 manifold   50.00    0   5.00  0.681167  103.772161
# 49                 manifold   50.00    1   5.00  0.642900   96.929276
#
#           sfid        is  precision    recall
# 0   126.834146  6.831919   0.329753  0.590333
# 1   119.912705  4.824308   0.491374  0.526333
# 2   123.533796  3.603296   0.630697  0.477667
# 3   134.853183  2.883460   0.733236  0.383667
# 4   153.782200  2.580580   0.774740  0.297000
# 5   124.057826  5.809196   0.376302  0.595667
# 6   120.376606  4.891800   0.462891  0.558667
# 7   121.883559  3.971615   0.575846  0.475667
# 8   126.010501  4.271632   0.537435  0.432000
# 9   129.193249  4.724464   0.463704  0.441000
# 10  125.932260  5.662430   0.366536  0.526000
# 11  122.639215  4.912847   0.457194  0.501333
# 12  124.345085  4.058665   0.555339  0.426333
# 13  128.427155  4.354723   0.513021  0.414333
# 14  131.432893  4.527506   0.466634  0.373333
# 15  125.332200  5.717573   0.369629  0.534667
# 16  122.000375  4.905808   0.453939  0.516333
# 17  123.916209  4.108930   0.547363  0.437667
# 18  128.038793  4.291682   0.516602  0.423000
# 19  130.813896  4.755501   0.464030  0.366333
# 20  142.822907  4.993328   0.337565  0.340667
# 21  137.827046  4.691991   0.400228  0.328667
# 22  136.216836  4.157808   0.494141  0.286333
# 23  137.916201  4.337092   0.459635  0.262000
# 24  138.378657  4.565199   0.427572  0.273000
# 25  135.361726  5.184460   0.348307  0.384667
# 26  131.560093  4.813465   0.409993  0.385667
# 27  132.167001  4.147334   0.513021  0.313000
# 28  134.674982  4.357339   0.470866  0.299333
# 29  136.354977  4.598354   0.436849  0.286000
# 30  124.460686  5.799283   0.374023  0.606000
# 31  120.602936  4.885393   0.472005  0.556333
# 32  121.501124  3.968958   0.577799  0.496333
# 33  125.694078  4.236371   0.540039  0.461333
# 34  129.044033  4.666203   0.472005  0.428667
# 35  128.661575  5.857702   0.375814  0.645333
# 36  123.807191  4.879608   0.475586  0.593667
# 37  122.766870  3.863851   0.591146  0.529333
# 38  126.286189  4.234324   0.554688  0.465667
# 39  129.125152  4.617061   0.493001  0.457667
# 40  123.285548  5.250512   0.430542  0.585500
# 41  119.824705  4.674417   0.476074  0.557333
# 42  126.471083  4.761488   0.485677  0.537667
# 43  119.447205  4.212489   0.539551  0.527667
# 44  132.285755  4.349319   0.479167  0.458000
# 45  121.722460  4.070835   0.564616  0.472333
# 46  138.757949  4.247049   0.444336  0.401333
# 47  128.485582  4.660506   0.486654  0.428667
# 48  137.249032  4.359073   0.433919  0.361000
# 49  130.401153  4.976264   0.417806  0.382667

# %%
# data = avg.loc[avg['mode'] == 'manifold']
data = avg
data = data.loc[data['validity'] > 0.6]
# data = data.loc[data['fid']<70]
data['eta-scale'] = data['eta'].astype(str) + '-' + data['scale'].astype(str)

# data['scale'] = data['scale'].map(lambda x: str(x))
plt.figure(figsize=(10,10), dpi=100)
sns.scatterplot(data=data, x='fid', y='validity', hue='eta-scale', style='mode', s=100)
# Out:
# /tmp/user/23218/ipykernel_3918108/1232312817.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['eta-scale'] = data['eta'].astype(str) + '-' + data['scale'].astype(str)
# <Axes: xlabel='fid', ylabel='validity'>

# %%
csv.loc[csv['mode'].isin(['manifold', 'dynamic-fonly'])].loc[csv['label'] == 1].sort_values(by=['mode', 'scale'])
# Out:
#                                            Name           mode  scale  label  \
# 102    guide_mode=dynamic-fonly+scale=2+label=1  dynamic-fonly    2.0      1
# 25     guide_mode=dynamic-fonly+scale=5+label=1  dynamic-fonly    5.0      1
# 4     guide_mode=dynamic-fonly+scale=20+label=1  dynamic-fonly   20.0      1
# 28    guide_mode=dynamic-fonly+scale=50+label=1  dynamic-fonly   50.0      1
# 65   guide_mode=dynamic-fonly+scale=100+label=1  dynamic-fonly  100.0      1
# 15          guide_mode=manifold+scale=1+label=1       manifold    1.0      1
# 5           guide_mode=manifold+scale=2+label=1       manifold    2.0      1
# 8           guide_mode=manifold+scale=5+label=1       manifold    5.0      1
# 56         guide_mode=manifold+scale=20+label=1       manifold   20.0      1
# 110        guide_mode=manifold+scale=50+label=1       manifold   50.0      1
#
#      validity        fid        sfid        is  precision  recall
# 102    0.3813  77.318172  124.520638  5.586083   0.329590   0.615
# 25     0.5913  51.794021  118.781807  4.395249   0.461426   0.558
# 4      0.8174  41.016895  120.525200  3.403000   0.583984   0.443
# 28     0.8403  53.079123  126.083413  3.457582   0.559082   0.384
# 65     0.8120  64.265418  126.881540  3.983398   0.479492   0.442
# 15     0.6523  48.452983  118.477048  4.190792   0.482422   0.559
# 5      0.7583  41.127577  117.742019  3.625943   0.551270   0.517
# 8      0.8374  43.015129  120.601504  3.541133   0.593750   0.453
# 56     0.8164  61.726525  127.401138  3.763835   0.516113   0.423
# 110    0.7456  78.389110  125.010881  4.274128   0.431152   0.379

# %%
csv = pd.read_csv("CIFAR+combine(part).csv")
# csv = csv.loc[(csv['mode'].isin(['manifold'])) ^ (csv['eta'] == 1)]
csv = csv.loc[~csv['mode'].str.contains('full')].loc[~csv['mode'].str.contains('one')].loc[~csv['mode'].str.contains('\*a-')]
csv
# Out:
#                                                   Name  \
# 0              guide_mode=classifier+scale=0.1+label=8
# 1              guide_mode=classifier+scale=0.1+label=6
# 2    guide_mode=dynamic-two-0.5*a*(1-a)+scale=20+la...
# 3    guide_mode=dynamic-two-0.1*a*(1-a)+scale=20+la...
# 4            guide_mode=dynamic-fonly+scale=20+label=1
# ..                                                 ...
# 410               guide_mode=manifold+scale=20+label=6
# 411               guide_mode=manifold+scale=20+label=8
# 412               guide_mode=manifold+scale=50+label=1
# 413               guide_mode=manifold+scale=50+label=6
# 414               guide_mode=manifold+scale=50+label=8
#
#                         mode  scale  label  eta  validity         fid  \
# 0                 classifier    0.1      8    1    0.3652   91.932738
# 1                 classifier    0.1      6    1    0.2471   90.925637
# 2    dynamic-two-0.5*a*(1-a)   20.0      1    1    0.8208   39.476015
# 3    dynamic-two-0.1*a*(1-a)   20.0      1    1    0.8135   40.359251
# 4              dynamic-fonly   20.0      1    1    0.8174   41.016895
# ..                       ...    ...    ...  ...       ...         ...
# 410                 manifold   20.0      6    0    0.4658  128.547993
# 411                 manifold   20.0      8    0    0.7637   53.479205
# 412                 manifold   50.0      1    0    0.7295   99.500889
# 413                 manifold   50.0      6    0    0.5049  142.991670
# 414                 manifold   50.0      8    0    0.8091   68.823923
#
#            sfid        is  precision  recall
# 0    114.626943  7.021482   0.350586   0.570
# 1    137.488113  6.851516   0.373047   0.574
# 2    122.032979  3.341644   0.606445   0.517
# 3    120.499850  3.390682   0.585938   0.474
# 4    120.525200  3.403000   0.583984   0.443
# ..          ...       ...        ...     ...
# 410  154.099395  5.139782   0.400879   0.502
# 411  114.970846  3.942854   0.534180   0.399
# 412  139.139870  3.925016   0.419922   0.276
# 413  155.255786  5.140246   0.392090   0.431
# 414  117.351438  4.011956   0.489746   0.376
#
# [265 rows x 11 columns]

# %%
# concert avg into a half table such that all eta = 0 and eta = 1 are concated in the same rows some long as the mode, scale are the same
avg = csv.pivot_table(index=['mode', 'scale', 'label'], columns='eta', values=['validity', 'fid', 'sfid', 'is', 'precision', 'recall'])
avg = avg.reset_index()
avg.columns = ["_".join([str(t) for t in w if t!='']) for w in avg.columns.values]
avg
# Out:
#            mode  scale  label       fid_0       fid_1      is_0      is_1  \
# 0    classifier   0.10      1   73.036794   91.316010  5.598959  6.622758
# 1    classifier   0.10      6   71.618125   90.925637  6.340681  6.851516
# 2    classifier   0.10      8   65.884177   91.932738  5.978353  7.021482
# 3    classifier   0.25      1   39.747365   50.804675  3.821718  4.372647
# 4    classifier   0.25      6   43.096277   60.222134  4.288852  5.336592
# ..          ...    ...    ...         ...         ...       ...       ...
# 130    manifold  20.00      6  128.547993   97.721244  5.139782  5.618134
# 131    manifold  20.00      8   53.479205   70.601545  3.942854  4.599549
# 132    manifold  50.00      1   99.500889   78.389110  3.925016  4.274128
# 133    manifold  50.00      6  142.991670  124.127553  5.140246  5.672109
# 134    manifold  50.00      8   68.823923   88.271165  4.011956  4.982554
#
#      precision_0  precision_1  recall_0  recall_1      sfid_0      sfid_1  \
# 0       0.368164     0.265625     0.644     0.627  127.635854  128.387383
# 1       0.438965     0.373047     0.647     0.574  134.625245  137.488113
# 2       0.419434     0.350586     0.568     0.570  115.120386  114.626943
# 3       0.555176     0.458496     0.538     0.554  117.630030  116.152275
# 4       0.612305     0.483398     0.589     0.553  131.381522  130.325553
# ..           ...          ...       ...       ...         ...         ...
# 130     0.400879     0.461426     0.502     0.460  154.099395  142.901684
# 131     0.534180     0.482422     0.399     0.403  114.970846  115.153924
# 132     0.419922     0.431152     0.276     0.379  139.139870  125.010881
# 133     0.392090     0.395020     0.431     0.400  155.255786  149.017778
# 134     0.489746     0.427246     0.376     0.369  117.351438  117.174799
#
#      validity_0  validity_1
# 0        0.3765      0.2544
# 1        0.3550      0.2471
# 2        0.4980      0.3652
# 3        0.6982      0.5557
# 4        0.6582      0.4985
# ..          ...         ...
# 130      0.4658      0.5610
# 131      0.7637      0.7637
# 132      0.7295      0.7456
# 133      0.5049      0.4976
# 134      0.8091      0.6855
#
# [135 rows x 15 columns]

# %%
data = avg.loc[~avg.isna().any(axis=1)]
data = data.loc[data['scale'] < 100]
data['scale'] = data['scale'].map(lambda x: str(x))

fig, axs= plt.subplots(nrows=1, ncols=2, figsize=(22, 10), dpi=100)

sns.scatterplot(data=data, x='fid_0', y='fid_1', hue='scale', style='mode', s=100, ax=axs[0])
axs[0].set_title("Comparison of FID between eta=0 and eta=1")
axs[0].legend(loc='upper left')
l, r = 25, 100
axs[0].set_xlim(l,r)
axs[0].set_ylim(l,r)
axs[0].plot([l,r], [l,r], 'r--')

sns.scatterplot(data=data, x='validity_0', y='validity_1', hue='scale', style='mode', s=100, ax=axs[1])
axs[1].set_title("Comparison of Validity between eta=0 and eta=1")
axs[1].legend(loc='lower right')
l, r = 0.6, 1
axs[1].set_xlim(l, r)
axs[1].set_ylim(l, r)
axs[1].plot([l,r], [l,r], 'r--')
